# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4]
y = [0, 1, 2, 3]
plt.step(x, y)
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np


def sigmoid(x):
    return 1 / (1 + np.exp((-x)))


my_samples = []
my_sigmoid = []

x = np.linspace(-10, 10, 10)
y = np.linspace(-10, 10, 100)

plt.plot(x, sigmoid(x), 'r', label='linspace(-10, 10, 10)')
plt.plot(y, sigmoid(y), 'r', label='linspace(-10, 10, 100')

plt.grid()

plt.title('sigmoid function')
plt.suptitle('Sigmoid')

plt.legend(loc='lower right')

plt.text(4, 0.8, r'$\sigma(x)=\frac{1}{1+e^(-x)}$', fontsize=20)
       
plt.show()

# %%
W = np.array([
               [0.9, 0.3],
               [0.2, 0.8]
             ])
I = np.array([1.0, 0.5], ndmin=2).T

print(I)

X = W.dot(I)

print(X)
# Out:
# [[1. ]
#  [0.5]]
# [[1.05]
#  [0.6 ]]

# %%
import math
wih = np.random.normal(0.0, math.pow(2, -0.5), (2, 3))
print(wih)

i = np.array([[1,2,3]]).T
print(wih.dot(i))
print(i)
# Out:
# [[-0.28952662 -0.36030947 -0.19551919]
#  [ 0.07216681 -1.17456343  0.79023653]]
# [[-1.59670314]
#  [ 0.09374952]]
# [[1]
#  [2]
#  [3]]
